# %%
import pandas as pd
import numpy as np

# %%
df_agri=pd.read_csv('../data/kp_agricultural_yields.csv')
df_infra=pd.read_csv('../data/kp_infrastructure_projects.csv')
df_subdistrict=pd.read_csv('../data/kp_subdistrict_development_index.csv')

# %%
df_agri.shape
# Out:
# (100000, 15)

# %%
print("Agricultural Dataset")
print(df_agri.shape)
print(df_agri.columns)
print(df_agri.describe())

print ("Infrastructure Dataset")
print(df_infra.shape)
print (df_agri.columns)
print(df_infra.describe())
print ("Subdistrict Dataset")
print (df_subdistrict.shape)
print (df_subdistrict.columns)
print (df_subdistrict.describe())
# Out:
# Agricultural Dataset
# (100000, 15)
# Index(['farm_id', 'district', 'crop_type', 'farm_size_acres',
#        'elevation_meters', 'soil_ph', 'fertilizer_used_bags_per_acre',
#        'organic_farming', 'irrigation_type', 'annual_rainfall_mm',
#        'average_temperature_celsius', 'pesticide_sprays_count',
#        'mechanization_level', 'distance_to_mandi_km',
#        'crop_yield_tons_per_acre'],
#       dtype='str')
#        farm_size_acres  elevation_meters        soil_ph  \
# count    100000.000000     100000.000000  100000.000000
# mean          4.629819       1091.058185       7.001101
# std           4.022543        752.675475       0.449034
# min           0.500000        180.000000       4.830000
# 25%           2.100000        410.300000       6.700000
# 50%           3.500000        895.000000       7.000000
# 75%           5.810000       1743.125000       7.300000
# max          73.590000       2600.000000       8.770000
#
# ...
